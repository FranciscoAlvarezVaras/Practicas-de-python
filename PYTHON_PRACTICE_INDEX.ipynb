# %% [markdown]
# <div align="center">
#
# # PRACTICA DE PYTHON
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/c/c3/Python-logo-notext.svg" width="120">
#
# ### Master en Big Data & Cloud - EDEM (MDA 2025/2026)
#
# **Autor:** Francisco Alvarez Varas | **Grupo:** MDAB
#
# ---
#
# **12 Guias Progresivas | 113 Ejercicios | De Cero a IA**
#
# *Inspirado en MIT 6.0001, Harvard CS50P y patrones de la industria real*
#
# </div>

# %% [markdown]
# ---
#
# ## Bienvenido!
#
# Este es el **hub central** de tu practica de Python. Aqui encontraras acceso a las 12 guias interactivas, cada una con ejercicios para practicar y soluciones ocultas para comparar.
#
# ### Como usar este notebook
#
# 1. **Abre la guia** que quieras practicar haciendo clic en el enlace
# 2. **Lee el ejercicio** con atencion
# 3. **Escribe tu codigo** en la celda marcada con `# TU CODIGO AQUI`
# 4. **Ejecuta la celda** (Shift+Enter) para ver el resultado
# 5. **Despliega la solucion** solo si te atascas (intenta primero!)
#
# ### Requisitos
#
# - **Python 3.8+** (Google Colab ya lo tiene)
# - **requests** (solo Guia 9): `!pip install requests`
# - **anthropic** (solo Guia 12, ej. 6): `!pip install anthropic`
# - No se necesitan `pandas`, `numpy` ni otras librerias. Todo con Python puro.

# %% [markdown]
# ---
#
# ## Indice de Guias
#
# ### Modulo Basico (Guias 1-4)
#
# *Fundamentos del lenguaje. Si nunca has programado, empieza aqui.*
#
# | # | Guia | Ejercicios | Nivel | Conceptos clave |
# |:---:|:-----|:---:|:---:|:---|
# | 01 | [**Variables, Tipos y Strings**](guia_01_variables_tipos_strings/guia_01.ipynb) | 9 | Basico | `int`, `float`, `str`, `bool`, f-strings, slicing, `type()`, `len()` |
# | 02 | [**Operadores y Condicionales**](guia_02_operadores_condicionales/guia_02.ipynb) | 12 | Basico | Aritmeticos, comparacion, logicos, `in`, `if/elif/else`, IMC, triangulos |
# | 03 | [**Listas, Tuplas y Diccionarios**](guia_03_listas_tuplas_diccionarios/guia_03.ipynb) | 8 | Intermedio | `list`, `tuple`, `dict`, `.append()`, `.get()`, matrices, inventarios |
# | 04 | [**Bucles For y While**](guia_04_bucles_for_while/guia_04.ipynb) | 13 | Intermedio | `for`, `while`, `range()`, `enumerate()`, `break`, primos, diamante |

# %% [markdown]
# ### Modulo Intermedio (Guias 5-7)
#
# *Funciones, clases y proyectos completos. El salto de calidad.*
#
# | # | Guia | Ejercicios | Nivel | Conceptos clave |
# |:---:|:-----|:---:|:---:|:---|
# | 05 | [**Funciones**](guia_05_funciones/guia_05.ipynb) | 18 | Intermedio | `def`, `return`, `*args`, `**kwargs`, lambda, recursion, `map()`, `filter()` |
# | 06 | [**Clases, Excepciones y Modulos**](guia_06_clases_excepciones_modulos/guia_06.ipynb) | 9 | Intermedio | `class`, `__init__`, herencia, `try/except`, decoradores, `import` |
# | 07 | [**Proyecto: Juegos Interactivos**](guia_07_proyecto_juegos/guia_07.ipynb) | 5 | Avanzado | Adivina palabra, Ahorcado, Piedra/Papel/Tijeras, Blackjack |

# %% [markdown]
# ### Modulo Avanzado (Guias 8-10)
#
# *Algoritmos, APIs y automatizacion. Nivel profesional.*
#
# | # | Guia | Ejercicios | Nivel | Conceptos clave |
# |:---:|:-----|:---:|:---:|:---|
# | 08 | [**Algoritmos estilo MIT**](guia_08_algoritmos_estilo_MIT/guia_08.ipynb) | 10 | Avanzado | Cesar, Scrabble, busqueda binaria, burbuja, Fibonacci, memoizacion |
# | 09 | [**APIs con Python**](guia_09_apis_con_python/guia_09.ipynb) | 9 | Avanzado | `requests`, JSON, REST, PokeAPI, NASA APOD, CoinGecko, paginacion |
# | 10 | [**Automatizacion de Datos**](guia_10_automatizacion_datos/guia_10.ipynb) | 8 | Avanzado | CSV, JSON, archivos, ETL pipeline, Logger, `os.path` |

# %% [markdown]
# ### Modulo Especializado (Guias 11-12)
#
# *Analisis de datos e integracion con IA. El cierre del ciclo.*
#
# | # | Guia | Ejercicios | Nivel | Conceptos clave |
# |:---:|:-----|:---:|:---:|:---|
# | 11 | [**Analisis de Datos (Harvard)**](guia_11_analisis_datos_harvard/guia_11.ipynb) | 6 | Avanzado | Datasets, estadisticas, recomendaciones, cifrado, Monte Carlo |
# | 12 | [**Proyecto IA (Anthropic/Claude)**](guia_12_proyecto_IA_anthropic/guia_12.ipynb) | 6 | Avanzado | Chatbot, NLP basico, Q&A, generador datos, pipeline ETL, Claude API |

# %% [markdown]
# ---
#
# ## Mapa de Conceptos
#
# ```
# GUIA 1: Variables          GUIA 2: Condicionales      GUIA 3: Estructuras
#    |                          |                          |
#    v                          v                          v
#  int, float, str           if/elif/else              list, dict, tuple
#  f-strings, len()          and, or, not              .append(), .get()
#  type(), rebanado           in, not in                rebanado, matrices
#         \                     |                        /
#          \                    |                       /
#           +-------------------+----------------------+
#                               |
#                               v
#                       GUIA 4: Bucles
#                        for, while
#                        range, enumerate
#                        break, continue
#                               |
#                  +------------+------------+
#                  |                         |
#                  v                         v
#           GUIA 5: Funciones        GUIA 6: Clases/OOP
#           def, return, lambda      class, __init__, self
#           *args, **kwargs          herencia, super()
#           recursion                try/except, decoradores
#                  |                         |
#                  +------------+------------+
#                               |
#                               v
#                     GUIA 7: Proyectos
#                     (combina todo lo anterior)
#                     Ahorcado, Blackjack, PDP
#                               |
#               +---------------+---------------+
#               |               |               |
#               v               v               v
#        GUIA 8: Algo      GUIA 9: APIs    GUIA 10: Auto
#        Busqueda binaria   requests        CSV, JSON
#        Ord. burbuja       REST APIs       ETL pipeline
#        Memoizacion        Paginacion      Registro
#               |               |               |
#               +---------------+---------------+
#                               |
#                  +------------+------------+
#                  |                         |
#                  v                         v
#         GUIA 11: Analisis         GUIA 12: IA
#         Datasets, Monte Carlo     Claude API
#         Recomendaciones           NLP, Chatbots
#         Estadisticas              Pipelines con IA
# ```

# %% [markdown]
# ---
#
# ## Resumen por numeros
#
# | Modulo | Guias | Ejercicios | Temas principales |
# |:-------|:-----:|:----------:|:---|
# | Basico | 1-4 | 42 | Variables, operadores, estructuras de datos, bucles |
# | Intermedio | 5-7 | 32 | Funciones, OOP, proyectos integradores |
# | Avanzado | 8-10 | 27 | Algoritmos, APIs REST, automatizacion |
# | Especializado | 11-12 | 12 | Analisis de datos, integracion con IA |
# | **TOTAL** | **12** | **113** | **De cero a IA con Python puro** |

# %% [markdown]
# ---
#
# ## Fuentes e inspiracion
#
# | Fuente | Que aporta |
# |:-------|:-----------|
# | [MIT 6.0001](https://ocw.mit.edu/courses/6-0001-introduction-to-computer-science-and-programming-in-python-fall-2016/) | Pensamiento computacional, biseccion, memoizacion, recursion |
# | [Harvard CS50P](https://cs50.harvard.edu/python/) | Ejercicios practicos, validacion de tipos |
# | [TheAlgorithms/Python](https://github.com/TheAlgorithms/Python) | Implementaciones de referencia de algoritmos clasicos |
# | [Anthropic Cookbook](https://github.com/anthropics/anthropic-cookbook) | Patrones de integracion con Claude API |
# | Ejercicios EDEM MDA 2025/2026 | Clases 1-4 del master (base de las guias 1-7) |

# %% [markdown]
# ---
#
# ## Quick Start - Prueba rapida
#
# Ejecuta la celda de abajo para verificar que todo funciona correctamente:

# %%
# Quick Start - Verifica que Python funciona correctamente
import sys
import os

print("=" * 50)
print("  PYTHON PRACTICE - EDEM MDA 2025/2026")
print("=" * 50)
print(f"\n  Python version: {sys.version.split()[0]}")
print(f"  Plataforma: {sys.platform}")
print(f"  Directorio: {os.getcwd()}")
print(f"\n  Estado: Todo listo para practicar!")
print(f"\n  Empieza por la Guia 01 si eres principiante")
print(f"  o salta a la guia que necesites repasar.")
print("\n" + "=" * 50)

# %% [markdown]
# ---
#
# ## Cada guia incluye:
#
# | Seccion | Descripcion |
# |:--------|:------------|
# | Navegacion | Enlaces a guia anterior y siguiente |
# | Tabla de info | Dificultad, numero de ejercicios, temas clave |
# | Prerequisitos | Que debes saber antes de empezar |
# | Conceptos clave | Teoria resumida con tablas y ejemplos |
# | Ejercicios | Enunciado + celda para tu codigo |
# | Soluciones ocultas | Desplegables con codigo comentado |
# | Tips y Recuerda | Resumen rapido de cada concepto |
# | Uso en el mundo real | Donde se aplica en la industria |
# | Errores comunes | Los fallos tipicos y como evitarlos |
# | Resumen final | Checklist de lo aprendido |
# | Para profundizar | Enlaces a MIT, Harvard, Real Python, docs oficiales |

# %% [markdown]
# ---
#
# <div align="center">
#
# ### Autor
#
# **Francisco Alvarez Varas**
#
# Master en Big Data & Cloud - EDEM (Grupo MDAB, 2025/2026)
#
# [LinkedIn](https://www.linkedin.com/in/frankalvarezv/) | Francisco92varas@gmail.com
#
# ---
#
# *"El mejor momento para plantar un arbol fue hace 20 anios. El segundo mejor momento es ahora."*
#
# *Empieza por la [Guia 01](guia_01_variables_tipos_strings/guia_01.ipynb) y avanza a tu ritmo!*
#
# </div>
